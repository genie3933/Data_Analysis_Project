# %% [markdown]
# # 멜론 데이터 전처리(1984~2020)
# * '데뷔곡' 컬럼 삭제
# * 팬수, 좋아요수 dtype을 object 타입에서 float 형태로 바꾸기
# * 2021년 데이터 삭제(형평성 문제 때문) 즉, 새로운 표준 데이터셋은 1984~2020년의 데이터가 범위가 되는 것
# * 가사컬럼 row 줄바꿈 없애기
# * 2020년 데이터까지만
# * Unnamed: 0컬럼 없애고 인덱스 정리
# * 결측치 있는 행 모두 0으로 처리
# * 스트리밍 서비스가 중지된 곡의 가사들은 '가사준비중~'으로 뜨기 때문에 '가사 없음'으로 처리
# * 19금 노래인 경우 가사와 제목에 전처리 필요
# * 제목에 같이 붙어있는 괄호와 괄호안의 소제목, 피쳐링 등 삭제

# %%
# 라이브러리 로드
import pandas as pd

# %%
# Unnamed: 0컬럼 없애고 인덱스 정리
melon_df = pd.read_csv('data/Melon_Data.csv', index_col=0)
melon_df = melon_df.drop(['Unnamed: 0.1'], axis = 1)
# 2020년 데이터 까지만
melon_df = melon_df[melon_df['연도'] <= 2020]

# %%
# 데이터 확인
melon_df.tail()
# Out:
#         연도   순위                 제목             가수                      앨범  \
# 95  2020.0   96  사계 (Four Seasons)  태연 (TAEYEON)        사계 (Four Seasons)
# 96  2020.0   97                찐이야            영탁        내일은 미스터트롯 결승전 베스트
# 97  2020.0   98                  비            폴킴                        비
# 98  2020.0   99       너에게 난, 나에게 넌       미도와 파라솔    슬기로운 의사생활 OST Part 12
# 99  2020.0  100              어떤 날엔           김재환       사랑의 불시착 OST Part 5
#
#       좋아요 수         발매일          장르  \
# 95  233,391  2019.03.24         발라드
# 96   60,261  2020.03.13        성인가요
# 97  280,647  2016.06.21    R&B/Soul
# 98   71,370  2020.05.29  발라드, 국내드라마
# 99   61,246  2020.01.19  발라드, 국내드라마
#
#                                                    가사  \
# 95  사계절이 와 그리고 또 떠나\n내 겨울을 주고 또 여름도 주었던\n온 세상이던 널 ...
# 96  찐찐찐찐 찐이야 완전 찐이야\n진짜가 나타났다 지금\n찐찐찐찐 찐이야 완전 찐이야\...
# 97  비가 내리다 말다\n우산을 챙길까 말까\ntv엔 맑음이라던데\n네 마음도 헷갈리나봐...
# 98  너에게 난 해질녘 노을처럼\n한편의 아름다운 추억이 되고\n소중했던 우리 푸르던 날...
# 99  어디쯤인 건지\n그대와 나 있는 곳 이렇게\n그저 떠올리기만 해도 나는\n떨림을 느...
#
#                                              작사/작곡/편곡       팬수  멤버수 솔로/그룹  성별  \
# 95  KENZIE\n작사\nJosh Cumbee\n작곡\nAfshin Salmani\n작...  230,517  1.0    솔로  여성
# 96  김지환\n작사\n알고보니 혼수상태\n작사\n김지환\n작곡\n알고보니 혼수상태\n작곡...   28,771  1.0    솔로  남성
# 97                          폴킴\n작사\n폴킴\n작곡\n조셉 케이\n편곡  151,273  1.0    솔로  남성
# 98    송봉주 (자전거 탄 풍경)\n작사\n송봉주 (자전거 탄 풍경)\n작곡\n이상훈\n편곡   11,105  5.0    그룹  혼성
# 99                        김호경\n작사\n1601\n작곡\n1601\n편곡   58,591  1.0    솔로  남성
#
#                                                   데뷔곡
# 95  데뷔곡\n솔로\nI (Feat. 버벌진트)\n태연 (TAEYEON)\n그룹\n다시 ...
# 96                                      데뷔곡\n사랑한다\n영탁
# 97                                데뷔곡\n커피 한 잔 할래요\n폴킴
# 98                                                NaN
# 99                                                NaN

# %%
# '데뷔곡' 컬럼 삭제
melon_df = melon_df.drop(['데뷔곡'], axis=1)
melon_df.head()
# Out:
#        연도  순위      제목    가수                       앨범  좋아요 수         발매일  \
# 0  1984.0   1      내일  김수철    작은 거인 김수철 (못다핀 꽃 한 송이)  2,172  1983.08.15
# 1  1984.0   2  그것은 인생  최혜영                     최혜영 1  1,157  1983.12.05
# 2  1984.0   3  잃어버린 정  김수희                     김수희 3    949  1984.01.30
# 3  1984.0   4     유리벽  신형원         신형원 베스트 1982-2000    693  2000.09.05
# 4  1984.0   5     J에게  이선희                   아! 옛날이여  2,375  1985.01.25
#
#        장르                                                 가사  \
# 0    록/메탈  스쳐가는 은빛 사연들이\n밤하늘에 가득차고\n풀나무에 맺힌 이슬처럼\n외로움이 찾아...
# 1    성인가요  나나나 나나나 나나나나\n나나나 나나나 나나나나\n아기 때는 젖주면 좋아하고 아하\...
# 2    성인가요  당신의 고운 눈매에 할말을 잊었지만은\n냉정히 돌아선 무정한 사람은 눈물을 모르겠지...
# 3  포크/블루스  내가 너의 손을 잡으려해도\n잡을수가 없었네\n보이지않는 그 무엇이\n나를 슬프게 ...
# 4     발라드  J 스치는 바람에 J 그대 모습 보이면\n난 오늘도 조용히 그댈 그리워하네\nJ 지...
#
#                     작사/작곡/편곡      팬수  멤버수 솔로/그룹  성별
# 0  김수철\n작사\n김수철\n작곡\n김수철\n편곡     886  1.0    솔로  남성
# 1  박건호\n작사\n김재일\n작곡\n김명곤\n편곡      67  1.0    솔로  여성
# 2  김중순\n작사\n김중순\n작곡\n이경석\n편곡     714  1.0    솔로  여성
# 3    한돌\n작사\n한돌\n작곡\n유지연\n편곡     362  1.0    솔로  여성
# 4           이세건\n작사\n이세건\n작곡  34,986  1.0    솔로  여성

# %%
# 데이터 info 확인
melon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3682 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   연도        3682 non-null   float64
#  1   순위        3682 non-null   int64
#  2   제목        3682 non-null   object
#  3   가수        3682 non-null   object
#  4   앨범        3682 non-null   object
#  5   좋아요 수     3682 non-null   object
#  6   발매일       3682 non-null   object
#  7   장르        3682 non-null   object
#  8   가사        3682 non-null   object
#  9   작사/작곡/편곡  3678 non-null   object
#  10  팬수        3677 non-null   object
#  11  멤버수       3665 non-null   float64
#  12  솔로/그룹     3665 non-null   object
#  13  성별        3665 non-null   object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 431.5+ KB

# %%
# 좋아요 수와 팬 수 컬럼의 데이터 타입 바꾸기
melon_df['좋아요 수'] = melon_df['좋아요 수'].str.replace(',', '').astype(float)
melon_df['팬수'] = melon_df['팬수'].str.replace(',', '').astype(float)

# %%
# 다시 info 확인
melon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3682 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   연도        3682 non-null   float64
#  1   순위        3682 non-null   int64
#  2   제목        3682 non-null   object
#  3   가수        3682 non-null   object
#  4   앨범        3682 non-null   object
#  5   좋아요 수     3682 non-null   float64
#  6   발매일       3682 non-null   object
#  7   장르        3682 non-null   object
#  8   가사        3682 non-null   object
#  9   작사/작곡/편곡  3678 non-null   object
#  10  팬수        3677 non-null   float64
#  11  멤버수       3665 non-null   float64
#  12  솔로/그룹     3665 non-null   object
#  13  성별        3665 non-null   object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 431.5+ KB

# %%
# 결측치 확인
melon_df.isnull().sum()
# Out:
# 연도           0
# 순위           0
# 제목           0
# 가수           0
# 앨범           0
# 좋아요 수        0
# 발매일          0
# 장르           0
# 가사           0
# 작사/작곡/편곡     4
# 팬수           5
# 멤버수         17
# 솔로/그룹       17
# 성별          17
# dtype: int64

# %%
# 결측치 0으로 채우기
melon_df = melon_df.fillna(0)

# %%
# 다시 결측치 확인
melon_df.isnull().sum()
# Out:
# 연도          0
# 순위          0
# 제목          0
# 가수          0
# 앨범          0
# 좋아요 수       0
# 발매일         0
# 장르          0
# 가사          0
# 작사/작곡/편곡    0
# 팬수          0
# 멤버수         0
# 솔로/그룹       0
# 성별          0
# dtype: int64

# %%
# \n 제거 (가사컬럼 row 줄바꿈 없애기)
melon_df = melon_df.replace('\n',' ', regex=True)

# %%
# 스트리밍 서비스가 중지되어 가사 준비중인 row의 경우 '가사 없음'으로 처리
melon_df['가사'][melon_df['가사'].str.contains('\[가사 준비중\] 멜론 회원 여러분!')] = '가사 없음'
# Out:
# <ipython-input-12-379dea948b30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melon_df['가사'][melon_df['가사'].str.contains('\[가사 준비중\] 멜론 회원 여러분!')] = '가사 없음'

# %%
melon_df['가사'].head(10)
# Out:
# 0    스쳐가는 은빛 사연들이 밤하늘에 가득차고 풀나무에 맺힌 이슬처럼 외로움이 찾아 드네...
# 1    나나나 나나나 나나나나 나나나 나나나 나나나나 아기 때는 젖주면 좋아하고 아하 아이...
# 2    당신의 고운 눈매에 할말을 잊었지만은 냉정히 돌아선 무정한 사람은 눈물을 모르겠지요...
# 3    내가 너의 손을 잡으려해도 잡을수가 없었네 보이지않는 그 무엇이 나를 슬프게 하였네...
# 4    J 스치는 바람에 J 그대 모습 보이면 난 오늘도 조용히 그댈 그리워하네 J 지난밤...
# 5    파티 파티가 시작될 때 나는 너를 보고 말았네 우린 처음 본 사람처럼 그냥 서로 인...
# 6                                                가사 없음
# 7    나 그대를 만나 추억을 잃어버렸네 보고 싶어서 날마다 찾았지만 만나면 안될 만나면 ...
# 8    하얀 목련이 필때면 다시 생각나는 사람 봄비내린 거리마다 슬픈 그대 뒷모습 하얀 눈...
# 9    언제 가셨는데 안오시나 한잎두고 가신님아 가지위에 눈물 적셔놓고 이는 바람소리 남겨...
# Name: 가사, dtype: object

# %%
# 19금 노래인 경우 가사 '가사 없음'으로 처리
melon_df['가사'][melon_df['가사'].str.contains('^청소년 보호법')] = '가사 없음'
# Out:
# <ipython-input-14-5236fd3ac853>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melon_df['가사'][melon_df['가사'].str.contains('^청소년 보호법')] = '가사 없음'

# %%
# 19금 노래의 경우 제목 앞에 '19금' 삭제
melon_df['제목'] = melon_df['제목'].str.replace('19금', '')

# %%
# 제목 괄호와 괄호안에 포함된 내용 제거
melon_df['제목'] = melon_df['제목'].str.replace(r"\(.*\)","")

# %%
# csv 파일로 저장
melon_df.to_csv('semi_final_melon_data.csv', encoding='utf-8-sig',index=False)

# %%
df = pd.read_csv('semi_final_melon_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   연도        3682 non-null   float64
#  1   순위        3682 non-null   int64
#  2   제목        3682 non-null   object
#  3   가수        3682 non-null   object
#  4   앨범        3682 non-null   object
#  5   좋아요 수     3682 non-null   float64
#  6   발매일       3682 non-null   object
#  7   장르        3682 non-null   object
#  8   가사        3682 non-null   object
#  9   작사/작곡/편곡  3682 non-null   object
#  10  팬수        3682 non-null   float64
#  11  멤버수       3682 non-null   float64
#  12  솔로/그룹     3682 non-null   object
#  13  성별        3682 non-null   object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 402.8+ KB

# %%
df.head(10)
# Out:
#        연도  순위          제목    가수                       앨범   좋아요 수         발매일  \
# 0  1984.0   1          내일  김수철    작은 거인 김수철 (못다핀 꽃 한 송이)  2172.0  1983.08.15
# 1  1984.0   2      그것은 인생  최혜영                     최혜영 1  1157.0  1983.12.05
# 2  1984.0   3      잃어버린 정  김수희                     김수희 3   949.0  1984.01.30
# 3  1984.0   4         유리벽  신형원         신형원 베스트 1982-2000   693.0  2000.09.05
# 4  1984.0   5         J에게  이선희                   아! 옛날이여  2375.0  1985.01.25
# 5  1984.0   6      눈물의 파티  조용필                    눈물의 파티   438.0  1984.02.09
# 6  1984.0   7       바보 바보  이동기              바보 바보/사랑의 아픔     4.0  1983.01.01
# 7  1984.0   8      눈물의 재회  강승모                     베스트 1    99.0  1983.01.01
# 8  1984.0   9       하얀 목련  양희은                 양희은 골든 15   323.0     1987.06
# 9  1984.0  10  못다핀 꽃 한 송이  김수철    작은 거인 김수철 (못다핀 꽃 한 송이)  4452.0  1983.08.15
#
#        장르                                                 가사  \
# 0    록/메탈  스쳐가는 은빛 사연들이 밤하늘에 가득차고 풀나무에 맺힌 이슬처럼 외로움이 찾아 드네...
# 1    성인가요  나나나 나나나 나나나나 나나나 나나나 나나나나 아기 때는 젖주면 좋아하고 아하 아이...
# 2    성인가요  당신의 고운 눈매에 할말을 잊었지만은 냉정히 돌아선 무정한 사람은 눈물을 모르겠지요...
# 3  포크/블루스  내가 너의 손을 잡으려해도 잡을수가 없었네 보이지않는 그 무엇이 나를 슬프게 하였네...
# 4     발라드  J 스치는 바람에 J 그대 모습 보이면 난 오늘도 조용히 그댈 그리워하네 J 지난밤...
# 5     발라드  파티 파티가 시작될 때 나는 너를 보고 말았네 우린 처음 본 사람처럼 그냥 서로 인...
# 6    성인가요                                              가사 없음
# 7    성인가요  나 그대를 만나 추억을 잃어버렸네 보고 싶어서 날마다 찾았지만 만나면 안될 만나면 ...
# 8  포크/블루스  하얀 목련이 필때면 다시 생각나는 사람 봄비내린 거리마다 슬픈 그대 뒷모습 하얀 눈...
# 9    록/메탈  언제 가셨는데 안오시나 한잎두고 가신님아 가지위에 눈물 적셔놓고 이는 바람소리 남겨...
#
#                                             작사/작곡/편곡       팬수  멤버수 솔로/그룹  성별
# 0                               김수철 작사 김수철 작곡 김수철 편곡    886.0  1.0    솔로  남성
# 1                               박건호 작사 김재일 작곡 김명곤 편곡     67.0  1.0    솔로  여성
# 2                               김중순 작사 김중순 작곡 이경석 편곡    714.0  1.0    솔로  여성
# 3                                 한돌 작사 한돌 작곡 유지연 편곡    362.0  1.0    솔로  여성
# 4                                      이세건 작사 이세건 작곡  34986.0  1.0    솔로  여성
# 5                               박건호 작사 이범희 작곡 이범희 편곡   9844.0  1.0    솔로  남성
# 6  vavi0219 국내 포크/블루스 29 오하이오바람 - 0 스토리버드 발라드 80 ...      8.0  1.0    솔로  남성
# 7                               박건호 작사 김영광 작곡 장세용 편곡    198.0  1.0    솔로  남성
# 8                                      양희은 작사 김희갑 작곡   7705.0  1.0    솔로  여성
# 9                               김수철 작사 김수철 작곡 김수철 편곡    886.0  1.0    솔로  남성
